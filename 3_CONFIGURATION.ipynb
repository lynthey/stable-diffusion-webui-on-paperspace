# %%
#(2) モデルのダウンロード（ここにダウンロードしたいモデルを追加）
# %cd /storage/stable-diffusion-webui/models/Stable-diffusion
# !wget -nc https://huggingface.co/personal1802/31/resolve/main/zhmixFantasy_v30.safetensors
# !wget -nc https://huggingface.co/digiplay/ZHMix-Dramatic-v3.0/resolve/refs%2Fpr%2F1/zhmixDramatic_v30.safetensors

#!wget -nc https://civitai.com/api/download/models/16859 -O BlueberryMix-1.0.safetensors
#!wget -nc https://civitai.com/api/download/models/11745 -O Chilloutmix-Ni-pruned-fp32-fix.safetensors
#!wget -nc https://huggingface.co/sazyou-roukaku/chilled_remix/resolve/5876389637f3f82d2b33a609f85f9b36aa4748fe/chilled_remix_v1vae.safetensors -O chilled_remix_v1vae.safetensors
#!wget -nc https://huggingface.co/sazyou-roukaku/chilled_remix/resolve/main/chilled_remix_v2.safetensors -O chilled_remix_v2.safetensors
#!wget -nc https://huggingface.co/nolanaatama/prfctwrld/resolve/main/prfctwrld.safetensors
#!wget -nc https://huggingface.co/fp16-guy/Fantexi_v0.9Beta_fp16_cleaned/resolve/main/fantexiV09beta_fantexiV09beta_fp16.safetensors
#!wget -nc https://huggingface.co/digiplay/ZHMix-Dramatic-v3.0/resolve/main/zhmixDramatic_v30.safetensors
#!wget -nc https://civitai.com/api/download/models/222442 -O zhmixFantasy_v30.safetensors 

# %cd /storage/stable-diffusion-webui/embeddings
# !wget -nc https://civitai.com/api/download/models/60938 -O negative_hand-neg.pt
# !wget -nc https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt_version2.pt -O bad_prompt.pt
# !wget -nc https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.safetensors
# !wget -nc https://huggingface.co/Neburozakusu/civitai_deposit/resolve/main/NG_DeepNegative_V1_75T.pt
# !wget -nc https://huggingface.co/yesyeahvh/bad-hands-5/resolve/main/bad-hands-5.pt

# %cd /storage/stable-diffusion-webui/models/ESRGAN
# !wget https://huggingface.co/lokCX/4x-Ultrasharp/resolve/main/4x-UltraSharp.pth

# %cd /storage/stable-diffusion-webui/models/Lora/
# !wget -nc https://huggingface.co/nolanaatama/fshngrl/resolve/main/fshngrl.safetensors
# !wget -nc https://huggingface.co/tomspy/shojovibe_v11.safetensors/resolve/main/shojovibe_v11.safetensors
#!wget -O shinyOiledSkin_v2.safetensors https://civitai.com/api/download/models/57468
# !wget -nc https://huggingface.co/ashen-sensored/mzpikas_tmnd_enhanced/resolve/main/Silicon-landscape-isolation.safetensors
# !wget -nc -O multipleassesv1.safetensors https://civitai.com/api/download/models/55644
# !wget -nc https://huggingface.co/naonovn/Lora/resolve/main/MultipleGirlsGroup.safetensors
# !wget -nc https://huggingface.co/naonovn/Lora/resolve/main/MultipleGirlsGroup.png
# !wget -nc https://huggingface.co/mlida/Cute_girl_mix4/resolve/main/cuteGirlMix4_v10.safetensors
# !wget -nc https://huggingface.co/ship01/AIdamoxing/resolve/main/GirlfriendMix2.safetensors
# !wget -nc -O Shinyoiledskin.safetensors https://civitai.com/api/download/models/57459
# !wget -nc -O Roleplaylingeriewithgarterbeltandskirts.safetensors https://civitai.com/api/download/models/164656
# !wget -nc -O eropose_allfours.safetensors https://civitai.com/api/download/models/102047
# !wget -nc -O Bubble_Bath.safetensors 'https://civitai.com/api/download/models/136541?type=Model&format=SafeTensor'
# !wget -nc -O bubblesuds.safetensors https://civitai.com/api/download/models/57654
# !wget -nc -O ShinyOiledSkin_v20-LyCORIS.safetensors 'https://civitai.com/api/download/models/57459?type=Model&format=SafeTensor'
# !wget -nc -O cumbath.safetensors 'https://civitai.com/api/download/models/132951?type=Model&format=SafeTensor'
# !wget -nc -O concept-pov-multiple_views-v1.safetensors 'https://civitai.com/api/download/models/60964?type=Model&format=SafeTensor'
# !wget -nc -O hairdetailer.safetensors 'https://civitai.com/api/download/models/86284?type=Model&format=SafeTensor'
# !wget -nc -O GoodHands-beta2.safetensors 'https://civitai.com/api/download/models/55199?type=Model&format=SafeTensor'
# !wget -nc https://huggingface.co/OedoSoldier/detail-tweaker-lora/resolve/main/add_detail.safetensors
# !wget -nc -O '0156 bubble bath_v1.safetensors' https://civitai.com/api/download/models/320694
# !wget -nc -O hiqcg_body_epoch.safetensors https://civitai.com/api/download/models/10301

# %cd /storage/stable-diffusion-webui/models/VAE
# !wget -nc https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors

# %cd /storage/stable-diffusion-webui/extensions/sd-webui-controlnet/models/
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.yaml
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.yaml
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.yaml
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.yaml
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth
# !wget -nc https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.yaml



# %cd /storage/stable-diffusion-webui/models/adetailer
# !wget https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8s.pt
# !wget https://huggingface.co/Bingsu/adetailer/resolve/main/hand_yolov8s.pt
# Out:
# /storage/stable-diffusion-webui-sd/models/Stable-diffusion
# File ‘zhmixFantasy_v30.safetensors’ already there; not retrieving.
#
# File ‘zhmixDramatic_v30.safetensors’ already there; not retrieving.
#
# /storage/stable-diffusion-webui-sd/embeddings
# File ‘negative_hand-neg.pt’ already there; not retrieving.
# File ‘bad_prompt.pt’ already there; not retrieving.
# File ‘EasyNegative.safetensors’ already there; not retrieving.
#
# --2024-05-12 06:51:12--  https://huggingface.co/Neburozakusu/civitai_deposit/resolve/main/NG_DeepNegative_V1_75T.pt
# Resolving huggingface.co (huggingface.co)... 18.238.49.10, 18.238.49.117, 18.238.49.70, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.10|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.
# File ‘bad-hands-5.pt’ already there; not retrieving.
#
# /storage/stable-diffusion-webui-sd/models/ESRGAN
# --2024-05-12 06:51:17--  https://huggingface.co/lokCX/4x-Ultrasharp/resolve/main/4x-UltraSharp.pth
# Resolving huggingface.co (huggingface.co)... 18.238.49.112, 18.238.49.70, 18.238.49.117, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/4f/c0/4fc02dc3831a1f63beb88d783b45af650d4846c8ae11dc90c3fb0efa99253386/a5812231fc936b42af08a5edba784195495d303d5b3248c24489ef0c4021fe01?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%274x-UltraSharp.pth%3B+filename%3D%224x-UltraSharp.pth%22%3B&Expires=1715754236&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=sumjb84SYOKMvmmlBgjtsHokEaxwpm1Yze9%7EnDeLs8ukBcJ5%7EH8m2xo2elrXVd7KSwFzOHRDsRf3rtn3Ai-ceJ0lOWUwJ9fpqDwPlZ6u2VFBrX5U0xYvc5qKmuGPvgRhWsLIwGRXpqzD94YFeJmzeVFcAjKo-EOSKS%7EWr1NGeQgEL4KqoMcDz4EeDUsbt-fMk2YTndgqVhXTxRQw75GZi8APxkasnV-WLK-3FDt4iVSom9dvVyNmAGBlgf%7E4PsaqwvchvnKa0C6kOFrAXxWpcz8RMzNuFK7miSsHUE8vxwXCULo1gOhcKggH5I2S3fkolAibI9p8Tz2GOz%7Enu01%7EkA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-05-12 06:51:17--  https://cdn-lfs.huggingface.co/repos/4f/c0/4fc02dc3831a1f63beb88d783b45af650d4846c8ae11dc90c3fb0efa99253386/a5812231fc936b42af08a5edba784195495d303d5b3248c24489ef0c4021fe01?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%274x-UltraSharp.pth%3B+filename%3D%224x-UltraSharp.pth%22%3B&Expires=1715754236&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=sumjb84SYOKMvmmlBgjtsHokEaxwpm1Yze9%7EnDeLs8ukBcJ5%7EH8m2xo2elrXVd7KSwFzOHRDsRf3rtn3Ai-ceJ0lOWUwJ9fpqDwPlZ6u2VFBrX5U0xYvc5qKmuGPvgRhWsLIwGRXpqzD94YFeJmzeVFcAjKo-EOSKS%7EWr1NGeQgEL4KqoMcDz4EeDUsbt-fMk2YTndgqVhXTxRQw75GZi8APxkasnV-WLK-3FDt4iVSom9dvVyNmAGBlgf%7E4PsaqwvchvnKa0C6kOFrAXxWpcz8RMzNuFK7miSsHUE8vxwXCULo1gOhcKggH5I2S3fkolAibI9p8Tz2GOz%7Enu01%7EkA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.164.116.66, 18.164.116.111, 18.164.116.15, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.164.116.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66961958 (64M) [binary/octet-stream]
# Saving to: ‘4x-UltraSharp.pth.2’
#
# 4x-UltraSharp.pth.2 100%[===================>]  63.86M   361MB/s    in 0.2s
#
# 2024-05-12 06:51:18 (361 MB/s) - ‘4x-UltraSharp.pth.2’ saved [66961958/66961958]
#
# /storage/stable-diffusion-webui-sd/models/Lora
# File ‘fshngrl.safetensors’ already there; not retrieving.
#
# File ‘shojovibe_v11.safetensors’ already there; not retrieving.
#
# File ‘Silicon-landscape-isolation.safetensors’ already there; not retrieving.
#
# File ‘multipleassesv1.safetensors’ already there; not retrieving.
# File ‘MultipleGirlsGroup.safetensors’ already there; not retrieving.
#
# File ‘MultipleGirlsGroup.png’ already there; not retrieving.
#
# File ‘cuteGirlMix4_v10.safetensors’ already there; not retrieving.
#
# File ‘GirlfriendMix2.safetensors’ already there; not retrieving.
#
# File ‘Shinyoiledskin.safetensors’ already there; not retrieving.
# File ‘Roleplaylingeriewithgarterbeltandskirts.safetensors’ already there; not retrieving.
# File ‘eropose_allfours.safetensors’ already there; not retrieving.
# File ‘Bubble_Bath.safetensors’ already there; not retrieving.
# File ‘bubblesuds.safetensors’ already there; not retrieving.
# File ‘ShinyOiledSkin_v20-LyCORIS.safetensors’ already there; not retrieving.
# File ‘cumbath.safetensors’ already there; not retrieving.
# File ‘concept-pov-multiple_views-v1.safetensors’ already there; not retrieving.
# File ‘hairdetailer.safetensors’ already there; not retrieving.
# File ‘GoodHands-beta2.safetensors’ already there; not retrieving.
# File ‘add_detail.safetensors’ already there; not retrieving.
#
# File ‘0156 bubble bath_v1.safetensors’ already there; not retrieving.
# --2024-05-12 06:51:26--  https://civitai.com/api/download/models/10301
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/118003/model/hiqcgBody768Epoch.yIET.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22hiqcg_body_768_epoch-000005.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240512/us-east-1/s3/aws4_request&X-Amz-Date=20240512T065127Z&X-Amz-SignedHeaders=host&X-Amz-Signature=bca8bbe04bc94c3f531cce8b2c5737297982819045894990a24b58f5400481d5 [following]
# --2024-05-12 06:51:27--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/118003/model/hiqcgBody768Epoch.yIET.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22hiqcg_body_768_epoch-000005.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240512/us-east-1/s3/aws4_request&X-Amz-Date=20240512T065127Z&X-Amz-SignedHeaders=host&X-Amz-Signature=bca8bbe04bc94c3f531cce8b2c5737297982819045894990a24b58f5400481d5
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151118680 (144M) [application/octet-stream]
# Saving to: ‘hiqcg_body_epoch.safetensors’
#
# hiqcg_body_epoch.sa 100%[===================>] 144.12M  98.4MB/s    in 1.5s
#
# 2024-05-12 06:51:28 (98.4 MB/s) - ‘hiqcg_body_epoch.safetensors’ saved [151118680/151118680]
#
# /storage/stable-diffusion-webui-sd/models/VAE
# File ‘vae-ft-mse-840000-ema-pruned.safetensors’ already there; not retrieving.
#
# /storage/stable-diffusion-webui-sd/extensions/sd-webui-controlnet/models
# File ‘control_v11f1e_sd15_tile.pth’ already there; not retrieving.
#
# File ‘control_v11f1e_sd15_tile.yaml’ already there; not retrieving.
#
# File ‘control_v11p_sd15_inpaint.pth’ already there; not retrieving.
#
# File ‘control_v11p_sd15_inpaint.yaml’ already there; not retrieving.
#
# File ‘control_v11p_sd15_openpose.pth’ already there; not retrieving.
#
# File ‘control_v11p_sd15_openpose.yaml’ already there; not retrieving.
#
# File ‘control_v11p_sd15_canny.pth’ already there; not retrieving.
#
# File ‘control_v11p_sd15_canny.yaml’ already there; not retrieving.
#
# File ‘control_v11f1p_sd15_depth.pth’ already there; not retrieving.
#
# File ‘control_v11f1p_sd15_depth.yaml’ already there; not retrieving.
#
# /storage/stable-diffusion-webui-sd/models/adetailer
# --2024-05-12 06:51:34--  https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8s.pt
# Resolving huggingface.co (huggingface.co)... 18.238.49.117, 18.238.49.70, 18.238.49.112, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.117|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/0d/db/0ddb8d3fcb6ee9737d9dd7e090e6c6cb6e40728d12307180160e7f654cb345de/6789a544b6747b6e6c099b01adfe118ff5ab93ecebda4d15f513ee91fc05c8ae?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27face_yolov8s.pt%3B+filename%3D%22face_yolov8s.pt%22%3B&Expires=1715753645&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=k2RVqEMhydIW06R0feTlH614LTkx4hFAIUpEuC38fpO1vL7t7kJmeJ0dV4X6maPACrLzIvKfXPZsiB%7EOzD30wjGh1gizn-Y9cUfwI3KMe%7EPcLGT5RZBEXoBW4jnrEQ2-3cOScSwfbXi0TtMHDw53Un9ALh5fU27NsZr-bp4%7E%7EC6at7Fo3uiZViM-%7Em2duS%7ELrYphAsUcJQH4aoOzvucnkR043p86WbwamXj-yYuZcznjuHFUY9vemRskXsYirz8zM8dwul955PN8XxnfDzsro9fynKM7NaEHp59KPJ1TsFFeYHAELDq439UCr4YNryV1FvLDnF9ONiL68hZjQmtZgw__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-05-12 06:51:34--  https://cdn-lfs.huggingface.co/repos/0d/db/0ddb8d3fcb6ee9737d9dd7e090e6c6cb6e40728d12307180160e7f654cb345de/6789a544b6747b6e6c099b01adfe118ff5ab93ecebda4d15f513ee91fc05c8ae?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27face_yolov8s.pt%3B+filename%3D%22face_yolov8s.pt%22%3B&Expires=1715753645&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=k2RVqEMhydIW06R0feTlH614LTkx4hFAIUpEuC38fpO1vL7t7kJmeJ0dV4X6maPACrLzIvKfXPZsiB%7EOzD30wjGh1gizn-Y9cUfwI3KMe%7EPcLGT5RZBEXoBW4jnrEQ2-3cOScSwfbXi0TtMHDw53Un9ALh5fU27NsZr-bp4%7E%7EC6at7Fo3uiZViM-%7Em2duS%7ELrYphAsUcJQH4aoOzvucnkR043p86WbwamXj-yYuZcznjuHFUY9vemRskXsYirz8zM8dwul955PN8XxnfDzsro9fynKM7NaEHp59KPJ1TsFFeYHAELDq439UCr4YNryV1FvLDnF9ONiL68hZjQmtZgw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.164.116.15, 18.164.116.66, 18.164.116.111, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.164.116.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22507771 (21M) [binary/octet-stream]
# Saving to: ‘face_yolov8s.pt.2’
#
# face_yolov8s.pt.2   100%[===================>]  21.46M  --.-KB/s    in 0.05s
#
# 2024-05-12 06:51:34 (410 MB/s) - ‘face_yolov8s.pt.2’ saved [22507771/22507771]
#
# --2024-05-12 06:51:34--  https://huggingface.co/Bingsu/adetailer/resolve/main/hand_yolov8s.pt
# Resolving huggingface.co (huggingface.co)... 18.238.49.70, 18.238.49.112, 18.238.49.10, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.70|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/0d/db/0ddb8d3fcb6ee9737d9dd7e090e6c6cb6e40728d12307180160e7f654cb345de/5c4faf8d17286ace2c3d3346c6d0d4a0c8d62404955263a7ae95c1dd7eb877af?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27hand_yolov8s.pt%3B+filename%3D%22hand_yolov8s.pt%22%3B&Expires=1715754072&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=rV7w8jUjozu4fFhttD-yxcgWXwCxQFRlXifTg8cSOXqpQS4o89TLExit-%7EMG93wC1EKLMdi1fEIyP-4gmavosmfwH-wCMZgN1OHIufQL%7EmO6imv%7ErbnGkbGo5999W8mMhBua5BWofMKkjBWMes4lecNCynMzU2c7ndTXCi895lswQIVE4KP9DX58VviK1%7EmbKHqcqfe9yqH-bcv-0DKyuQg-HLhvvfDfSakrv2ksvKLNluUIOUhpvOxeat5T91tsHd-6HCjzO3eoyw8wRwiCm2sHWa388JZv4S9oWPz7f2006Ldq3YLFNdir8Z9pYrjmcLoSOMx7N0oCrIsV9fUUDg__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-05-12 06:51:34--  https://cdn-lfs.huggingface.co/repos/0d/db/0ddb8d3fcb6ee9737d9dd7e090e6c6cb6e40728d12307180160e7f654cb345de/5c4faf8d17286ace2c3d3346c6d0d4a0c8d62404955263a7ae95c1dd7eb877af?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27hand_yolov8s.pt%3B+filename%3D%22hand_yolov8s.pt%22%3B&Expires=1715754072&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=rV7w8jUjozu4fFhttD-yxcgWXwCxQFRlXifTg8cSOXqpQS4o89TLExit-%7EMG93wC1EKLMdi1fEIyP-4gmavosmfwH-wCMZgN1OHIufQL%7EmO6imv%7ErbnGkbGo5999W8mMhBua5BWofMKkjBWMes4lecNCynMzU2c7ndTXCi895lswQIVE4KP9DX58VviK1%7EmbKHqcqfe9yqH-bcv-0DKyuQg-HLhvvfDfSakrv2ksvKLNluUIOUhpvOxeat5T91tsHd-6HCjzO3eoyw8wRwiCm2sHWa388JZv4S9oWPz7f2006Ldq3YLFNdir8Z9pYrjmcLoSOMx7N0oCrIsV9fUUDg__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.164.116.66, 18.164.116.111, 18.164.116.106, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.164.116.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22507707 (21M) [binary/octet-stream]
# Saving to: ‘hand_yolov8s.pt.2’
#
# hand_yolov8s.pt.2   100%[===================>]  21.46M  --.-KB/s    in 0.06s
#
# 2024-05-12 06:51:34 (341 MB/s) - ‘hand_yolov8s.pt.2’ saved [22507707/22507707]

# %%
#GIT UPDATE
# %cd /storage/stable-diffusion-webui
# !git checkout master
# !git pull
# Out:
# /storage/stable-diffusion-webui
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# remote: Enumerating objects: 516, done.
# remote: Counting objects: 100% (424/424), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 516 (delta 344), reused 373 (delta 313), pack-reused 92
# Receiving objects: 100% (516/516), 256.06 KiB | 4.66 MiB/s, done.
# Resolving deltas: 100% (356/356), completed with 74 local objects.
# From https://github.com/AUTOMATIC1111/stable-diffusion-webui
#    cf2772fa..bef51aed  master            -> origin/master
#    18819723..45b8a499  dev               -> origin/dev
#    43850655..40e4ca99  gradio4           -> origin/gradio4
#    30697165..13984857  release_candidate -> origin/release_candidate
#  * [new tag]           v1.8.0            -> v1.8.0
# Updating cf2772fa..bef51aed
# Updating files: 100% (153/153), done.
# Fast-forward
#  .eslintrc.js                                       |    2 -
#  .github/workflows/run_tests.yaml                   |   10 +-
#  .gitignore                                         |    1 +
#  CHANGELOG.md                                       |  132 +++
#  README.md                                          |   13 +-
#  configs/sd_xl_inpaint.yaml                         |   98 ++
#  extensions-builtin/Lora/network.py                 |   35 +-
#  extensions-builtin/Lora/network_full.py            |    4 +-
#  extensions-builtin/Lora/network_glora.py           |   10 +-
#  extensions-builtin/Lora/network_hada.py            |   12 +-
#  extensions-builtin/Lora/network_ia3.py             |    2 +-
#  extensions-builtin/Lora/network_lokr.py            |   18 +-
#  extensions-builtin/Lora/network_lora.py            |    6 +-
#  extensions-builtin/Lora/network_norm.py            |    4 +-
#  extensions-builtin/Lora/network_oft.py             |  100 +-
#  extensions-builtin/Lora/networks.py                |   42 +-
#  extensions-builtin/Lora/preload.py                 |    5 +-
#  extensions-builtin/Lora/scripts/lora_script.py     |    2 +
#  extensions-builtin/Lora/ui_edit_user_metadata.py   |    9 +-
#  extensions-builtin/Lora/ui_extra_networks_lora.py  |   10 +-
#  extensions-builtin/ScuNET/scripts/scunet_model.py  |   94 +-
#  extensions-builtin/ScuNET/scunet_model_arch.py     |  268 ------
#  extensions-builtin/SwinIR/scripts/swinir_model.py  |  163 +---
#  extensions-builtin/SwinIR/swinir_model_arch.py     |  867 -----------------
#  extensions-builtin/SwinIR/swinir_model_arch_v2.py  | 1017 --------------------
#  .../canvas-zoom-and-pan/javascript/zoom.js         |    8 +-
#  .../canvas-zoom-and-pan/scripts/hotkey_config.py   |    4 +-
#  .../scripts/extra_options_section.py               |    4 +-
#  .../soft-inpainting/scripts/soft_inpainting.py     |  747 ++++++++++++++
#  html/extra-networks-card.html                      |   17 +-
#  html/extra-networks-copy-path-button.html          |    5 +
#  html/extra-networks-edit-item-button.html          |    4 +
#  html/extra-networks-metadata-button.html           |    4 +
#  html/extra-networks-pane.html                      |   55 ++
#  html/extra-networks-tree-button.html               |   23 +
#  html/licenses.html                                 |  310 +-----
#  javascript/extensions.js                           |    7 +-
#  javascript/extraNetworks.js                        |  511 +++++++---
#  javascript/progressbar.js                          |    9 +-
#  javascript/resizeHandle.js                         |  137 ++-
#  javascript/settings.js                             |    4 +-
#  javascript/token-counters.js                       |   34 +-
#  javascript/ui.js                                   |   23 +-
#  modules/api/api.py                                 |  153 ++-
#  modules/api/models.py                              |    4 +
#  modules/cache.py                                   |   17 +-
#  modules/call_queue.py                              |    1 +
#  modules/cmd_args.py                                |   47 +-
#  modules/codeformer/codeformer_arch.py              |  276 ------
#  modules/codeformer/vqgan_arch.py                   |  435 ---------
#  modules/codeformer_model.py                        |  158 +--
#  modules/dat_model.py                               |   79 ++
#  modules/devices.py                                 |  114 ++-
#  modules/errors.py                                  |    4 +-
#  modules/esrgan_model.py                            |  199 +---
#  modules/esrgan_model_arch.py                       |  465 ---------
#  modules/extensions.py                              |   16 +-
#  modules/extra_networks.py                          |    5 +-
#  modules/face_restoration_utils.py                  |  180 ++++
#  modules/gfpgan_model.py                            |  166 ++--
#  modules/hashes.py                                  |    5 +-
#  modules/hat_model.py                               |   43 +
#  modules/images.py                                  |   16 +-
#  modules/img2img.py                                 |    7 +-
#  ...n_parameters_copypaste.py => infotext_utils.py} |  127 ++-
#  modules/infotext_versions.py                       |   42 +
#  modules/initialize.py                              |    8 +-
#  modules/initialize_util.py                         |    2 +
#  modules/interrogate.py                             |    6 +-
#  modules/launch_utils.py                            |   39 +-
#  modules/logging_config.py                          |   63 +-
#  modules/masking.py                                 |   43 +-
#  modules/modelloader.py                             |   92 +-
#  modules/npu_specific.py                            |   31 +
#  modules/options.py                                 |   35 +-
#  modules/paths.py                                   |    1 -
#  modules/paths_internal.py                          |    5 +
#  modules/postprocessing.py                          |   15 +-
#  modules/processing.py                              |  239 ++++-
#  modules/processing_scripts/comments.py             |   42 +
#  modules/processing_scripts/refiner.py              |    7 +-
#  modules/processing_scripts/seed.py                 |   32 +-
#  modules/progress.py                                |   22 +-
#  modules/realesrgan_model.py                        |  158 ++-
#  modules/script_callbacks.py                        |   31 +-
#  modules/scripts.py                                 |  131 ++-
#  modules/sd_emphasis.py                             |   70 ++
#  modules/sd_hijack_clip.py                          |   21 +-
#  modules/sd_hijack_clip_old.py                      |    2 +-
#  modules/sd_hijack_utils.py                         |   12 +-
#  modules/sd_models.py                               |  106 +-
#  modules/sd_models_config.py                        |    6 +-
#  modules/sd_models_xl.py                            |   11 +-
#  modules/sd_samplers.py                             |    3 +-
#  modules/sd_samplers_cfg_denoiser.py                |   95 +-
#  modules/sd_samplers_common.py                      |    7 +
#  modules/sd_samplers_kdiffusion.py                  |    6 +-
#  modules/sd_samplers_lcm.py                         |  104 ++
#  modules/sd_samplers_timesteps.py                   |    9 +-
#  modules/sd_vae.py                                  |    3 +-
#  modules/shared.py                                  |    3 +-
#  modules/shared_gradio_themes.py                    |    4 +
#  modules/shared_init.py                             |    5 +-
#  modules/shared_items.py                            |    9 +-
#  modules/shared_options.py                          |   44 +-
#  modules/shared_state.py                            |    7 +
#  modules/styles.py                                  |  158 ++-
#  modules/sysinfo.py                                 |    4 +-
#  modules/textual_inversion/textual_inversion.py     |   11 +-
#  modules/torch_utils.py                             |   17 +
#  modules/txt2img.py                                 |   65 +-
#  modules/ui.py                                      |  210 ++--
#  modules/ui_common.py                               |  184 +++-
#  modules/ui_extensions.py                           |    4 +-
#  modules/ui_extra_networks.py                       |  608 ++++++++----
#  modules/ui_extra_networks_checkpoints.py           |    8 +-
#  modules/ui_extra_networks_hypernets.py             |    6 +-
#  modules/ui_extra_networks_textual_inversion.py     |    5 +-
#  modules/ui_extra_networks_user_metadata.py         |    6 +-
#  modules/ui_gradio_extensions.py                    |   19 +-
#  modules/ui_loadsave.py                             |    7 +-
#  modules/ui_postprocessing.py                       |   15 +-
#  modules/ui_prompt_styles.py                        |    9 +-
#  modules/ui_tempdir.py                              |   24 +-
#  modules/ui_toprow.py                               |   35 +-
#  modules/upscaler.py                                |    3 +
#  modules/upscaler_utils.py                          |  190 ++++
#  modules/util.py                                    |   90 +-
#  modules/xlmr.py                                    |    5 +-
#  modules/xlmr_m18.py                                |    4 +-
#  modules/xpu_specific.py                            |   91 +-
#  requirements.txt                                   |    5 +-
#  requirements_npu.txt                               |    4 +
#  requirements_versions.txt                          |   10 +-
#  script.js                                          |   31 +-
#  scripts/loopback.py                                |    6 +-
#  scripts/postprocessing_caption.py                  |    4 +-
#  scripts/postprocessing_create_flipped_copies.py    |    2 +-
#  scripts/postprocessing_focal_crop.py               |    2 +-
#  scripts/postprocessing_split_oversized.py          |    2 +-
#  scripts/postprocessing_upscale.py                  |    6 +-
#  scripts/processing_autosized_crop.py               |    2 +-
#  scripts/xyz_grid.py                                |   32 +-
#  style.css                                          |  572 +++++++++--
#  test/conftest.py                                   |   15 +-
#  test/test_face_restorers.py                        |   29 +
#  test/test_files/two-faces.jpg                      |  Bin 0 -> 14768 bytes
#  test/test_outputs/.gitkeep                         |    0
#  test/test_torch_utils.py                           |   19 +
#  webui-macos-env.sh                                 |    2 +-
#  webui.py                                           |    2 +-
#  webui.sh                                           |   54 +-
#  152 files changed, 5883 insertions(+), 5612 deletions(-)
#  create mode 100644 configs/sd_xl_inpaint.yaml
#  delete mode 100644 extensions-builtin/ScuNET/scunet_model_arch.py
#  delete mode 100644 extensions-builtin/SwinIR/swinir_model_arch.py
#  delete mode 100644 extensions-builtin/SwinIR/swinir_model_arch_v2.py
#  create mode 100644 extensions-builtin/soft-inpainting/scripts/soft_inpainting.py
#  create mode 100644 html/extra-networks-copy-path-button.html
#  create mode 100644 html/extra-networks-edit-item-button.html
#  create mode 100644 html/extra-networks-metadata-button.html
#  create mode 100644 html/extra-networks-pane.html
#  create mode 100644 html/extra-networks-tree-button.html
#  delete mode 100644 modules/codeformer/codeformer_arch.py
#  delete mode 100644 modules/codeformer/vqgan_arch.py
#  create mode 100644 modules/dat_model.py
#  delete mode 100644 modules/esrgan_model_arch.py
#  create mode 100644 modules/face_restoration_utils.py
#  create mode 100644 modules/hat_model.py
#  rename modules/{generation_parameters_copypaste.py => infotext_utils.py} (79%)
#  create mode 100644 modules/infotext_versions.py
#  create mode 100644 modules/npu_specific.py
#  create mode 100644 modules/processing_scripts/comments.py
#  create mode 100644 modules/sd_emphasis.py
#  create mode 100644 modules/sd_samplers_lcm.py
#  create mode 100644 modules/torch_utils.py
#  create mode 100644 modules/upscaler_utils.py
#  create mode 100644 requirements_npu.txt
#  create mode 100644 test/test_face_restorers.py
#  create mode 100644 test/test_files/two-faces.jpg
#  create mode 100644 test/test_outputs/.gitkeep
#  create mode 100644 test/test_torch_utils.py

# %%
#CLEAN DOWNLOAD(GIT CLONE)
# %cd /storage
# !rm -rf stable-diffusion-webui
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# Out:
# /notebooks
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 27956, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 27956 (delta 55), reused 70 (delta 38), pack-reused 27857
# Receiving objects: 100% (27956/27956), 32.52 MiB | 58.83 MiB/s, done.
# Resolving deltas: 100% (19559/19559), done.
